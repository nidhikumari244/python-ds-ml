# %%
# import pandas as pd 
# data =[1,2,3,4,5]
# series = pd.Series(data)
# print("series\n,"series)

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\nidhi\OneDrive\Desktop\desktop-folder\Code\venv\python.exe

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\nidhi\OneDrive\Desktop\desktop-folder\Code\venv\Scripts\python.exe

# %%
import pandas as pd

# %%
## series 
import pandas as pd
data =[1,2,3,4]
series=pd.Series(data) 
print("series\n",series)
# Out:
# series
#  0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
data = {'a':1,'b':2,'c':3}
series_dict=pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data =[10,20,30]
index=['a','b','c']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
##DAta frame
#create a dtaframe form dictonary of list

data={
    'Name':['nidhi','bhaiya','radhe','krishna'],
    'age':[20,22,111000,1110000],
    'City':['lucknow','newyork','man ke marji','man ke marji ke piche']
}
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#       Name      age                   City
# 0    nidhi       20                lucknow
# 1   bhaiya       22                newyork
# 2    radhe   111000           man ke marji
# 3  krishna  1110000  man ke marji ke piche
# <class 'pandas.DataFrame'>

# %%
data=[
    {'name': 'nidhi','age':20,'city':'lucknow'},
    {'name': 'bhaiya','age':22,'city':'newyork'},
    {'name': 'radha krishna','age':20000000,'city':'heart'},
    {'name': 'krishna','age':111111110,'city':'inside that heart'}
]
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#             name        age               city
# 0          nidhi         20            lucknow
# 1         bhaiya         22            newyork
# 2  radha krishna   20000000              heart
# 3        krishna  111111110  inside that heart
# <class 'pandas.DataFrame'>

# %%
# df= pd.read_csv('sales_data.csv')
# df.head(5)

data
# Out:
# [{'name': 'nidhi', 'age': 20, 'city': 'lucknow'},
#  {'name': 'bhaiya', 'age': 22, 'city': 'newyork'},
#  {'name': 'radha', 'age': 20000000, 'city': 'heart'},
#  {'name': 'krishna', 'age': 111111110, 'city': 'inside that heart'}]

# %%
df['name']
# Out:
# 0      nidhi
# 1     bhaiya
# 2      radha
# 3    krishna
# Name: name, dtype: str

# %%
df.loc[0]
# Out:
# name      nidhi
# age          20
# city    lucknow
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# name     bhaiya
# age          22
# city    newyork
# Name: 1, dtype: object

# %%
df
# Out:
#       name        age               city
# 0    nidhi         20            lucknow
# 1   bhaiya         22            newyork
# 2    radha   20000000              heart
# 3  krishna  111111110  inside that heart

# %%
## accesing a specified element
df.at[1,'age']
# Out:
# np.int64(22)

# %%
df.at[2,'name']
# Out:
# 'radha'

# %%
df.iat[2,2]
# Out:
# 'heart'

# %%
## data manupulation with dataframe

df
# Out:
#       name        age               city
# 0    nidhi         20            lucknow
# 1   bhaiya         22            newyork
# 2    radha   20000000              heart
# 3  krishna  111111110  inside that heart

# %%
df['Salary']=[500000000,50000000000000000000,100000000,123456789]
df
# Out:
#       name        age               city                Salary
# 0    nidhi         20            lucknow             500000000
# 1   bhaiya         22            newyork  50000000000000000000
# 2    radha   20000000              heart             100000000
# 3  krishna  111111110  inside that heart             123456789

# %%
df.drop('age',axis=1,inplace=True)

# %%
df
# Out:
#       name               city                Salary
# 0    nidhi            lucknow             500000000
# 1   bhaiya            newyork  50000000000000000000
# 2    radha              heart             100000000
# 3  krishna  inside that heart             123456789

# %%
df['Salary']=df['Salary']+1000000

# %%
df
# Out:
#       name               city                Salary
# 0    nidhi            lucknow             501000000
# 1   bhaiya            newyork  50000000000001000000
# 2    radha              heart             101000000
# 3  krishna  inside that heart             124456789

# %%
df.drop(3,inplace=True)

# %%
df
# Out:
#             name       age     city
# 0          nidhi        20  lucknow
# 1         bhaiya        22  newyork
# 2  radha krishna  20000000    heart

# %%
df.describe()
# Out:
#                 age
# count  3.000000e+00
# mean   6.666681e+06
# std    1.154699e+07
# min    2.000000e+01
# 25%    2.100000e+01
# 50%    2.200000e+01
# 75%    1.000001e+07
# max    2.000000e+07
