# %%
import sys
print(sys.executable)
# Out:
# C:\Users\nidhi\OneDrive\Desktop\desktop-folder\Code\python-ds-ml\myenv\Scripts\python.exe

# %%
import kiwisolver
print(kiwisolver.__file__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import kiwisolver
#       2 print(kiwisolver.__file__)
#
# ModuleNotFoundError: No module named 'kiwisolver'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\nidhi\OneDrive\Desktop\desktop-folder\Code\python-ds-ml\myenv\Scripts\python.exe
