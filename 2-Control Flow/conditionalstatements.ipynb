# %%
##if statements 
age = 20
if age>=18:
    print("u r elligible for the vote in election")
# Out:
# u r elligible for the vote in election

# %%
age>=18
# Out:
# True

# %%
age<=18
# Out:
# False

# %%
##ELSE STATEment

age= 16
if age>=18:
    print("u r elligible for the voting")
else:
    print("u r minor")
# Out:
# u r minor

# %%
#elif
age=20
if age<13:
    print("u r child")
elif age<18:
    print("u r a teenager")
else:
    print("u r an adult")
# Out:
# u r an adult

# %%
##NESTED conditional statements

## u can put more than on if, elif, else statement inside another if , elif, else

num = int(input("enter a no."))
if num>0:
    print(num," is positive number")
    if num % 2==0:
        print("and is an even no.")
    else:
        print("and  an odd no.")
elif num==0:
    print("it is zero")
else:
    print(num," is a negative no")
# Out:
# -9  is a negative no

# %%
## EXAMPLE using nested loop

## determine LEAP YEAR

year= int(input("Enter a year u want to check"))
if year % 4==0: 
    if year%100==0:
        if (year%400==0):
            print(year,"is leap year")
        else:
            print(year, "is not a leap year")
    else:
        print(year,"is leap year")
else:
    print(year,"not a leap year")
# Out:
# 2024 is leap year

# %%
## CALCULATOR using nested loop

num1=float(input("enter 1st no."))
num2=float(input("enter 2nd no."))
operation=input("enter operation(+,-,*,/,//,%):")
if operation =='+':
    result= num1+num2
elif operation=='-':
    result= num1-num2
elif operation=='*':
    result= num1*num2
elif operation=='/':
    if num2!=0:
        result= num1/num2
    else:
        result= "error!! Division by 0 "
elif operation=='//':
    result= num1//num2
elif operation=='%':
    result= num1%num2
else:
    result="invalid operation"
print("result: ",result)
# Out:
# result:  0.7818181818181819

# %%
## Determine the ticket price based on age and whether the person is student 
age = int(input("enter the age"))
is_student=input("Are u a student?(yes/No): ").lower()

if age<=5:
    price="Free"
elif age<=12:
    price="$5"
elif age<= 17:
    if is_student == 'yes':
        price="$12"
    else:
        price="$15"
elif age<=60:
    if is_student=='yes':
        price="$18"
    else:
        price= "$25"
else:
    price="$22"
print("ticket price:", price)
# Out:
# ticket price: $25
