# %%
a= 100

# %%
## declearing and assiging variables

age = 32
height = 5.2
name = " nidhi"
is_student =True

## printing the variables

print("age :", age)
print("height:", height)
print("name:", name)
# Out:
# age : 32
# height: 5.2
# name:  nidhi

# %%
#naming conversion 
# variables names should be descriptive
# the must start with a letter or an '_' and contains letter, numbers and underscores
# variables

# %%
age = 20
print(type(age))

# type conversion 
age_str=str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 20
# <class 'str'>

# %%
height=5.2
type(height)
# Out:
# float

# %%
float(int(height))
# Out:
# 5.0

# %%
#dynamic typing
# pt alows the type of a variable to change as the prog. execute
var = 10 #int
print(var,type(var))

var= "hlo"
print (var,type(var))

var = 3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# hlo <class 'str'>
# 3.14 <class 'float'>

# %%
age =int( input("what is the age"))
print(age,type(age))
# Out:
# 20 <class 'int'>

# %%
### SIMPLE CALCULATOR

num1= float (input ("enter first no."))
num2 = float(input("enter second no."))
sum = num1+num2
difference= num1-num2
product = num1 * num2
quotient= num1/num2

print("sum:", sum)
print("difference:", difference)
print("product:", product)
print("quotient:", quotient)
# Out:
# sum: 26.0
# difference: -2.0
# product: 168.0
# quotient: 0.8571428571428571
