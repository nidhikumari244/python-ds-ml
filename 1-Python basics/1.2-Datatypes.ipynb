# %%
#integer dataType ex
age = 35
type(age)
# Out:
# int

# %%
# floating point datatype

height=5.2
print (height)
print(type(height))
# Out:
# 5.2
# <class 'float'>

# %%
#string DataType 
name="NIDHI"
print(name)
print(type(name))
# Out:
# NIDHI
# <class 'str'>

# %%
#Boolean datatype
is_true=True
type(is_true)
# Out:
# bool

# %%
a=12
b=4

type(a==b)
# Out:
# bool

# %%
#comman error
#----Type Casting----

# result="hello" + 5
# print(result) 

result="hello" + "5"
#OR-- result = "hello " + str(5)
print (result)
# Out:
# hello 5
