# %%
## Basics syntax rules in python 
## Case sensitive python in case sensitive 

name = "NIdhi"
Name = "kumari"

print (name)
print (Name)
# Out:
# NIdhi
# kumari

# %%
# indentation 

age = 22
if age > 30:
    print(age)
    
print (age)
# Out:
# 22

# %%
##line continuation -----use baclslash(\) to continue a statement to the next line 
# single statement in single line 
total = 12+2+3+8+ \
    4+5
print(total)
# Out:
# 34

# %%
## multiple statements on single line 
x=5;y=12;z=x-y
print(z)
# Out:
# -7

# %%
## Understanding Sementics in Python 
# variable assignment 
age = 20
name="NIDHI"

# %%
#type inference
type(age)
# Out:
# int

# %%
#type infernce
variable = 10
print(type(variable))
variable="NDH"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a=12
b=a
print(b)
# Out:
# 12

# %%
## code example if indentation
if True:
    print("correct indentation")
    if False:
        print("this not print")
    print("this will print")
print("outside the if block")
# Out:
# correct indentation
# this will print
# outside the if block

# %%
type(name)
# Out:
# str
